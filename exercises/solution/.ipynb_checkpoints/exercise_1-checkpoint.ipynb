# %% [markdown]
# # Exercise 1. DL2 files and PINT

# %%
import pandas as pd
import os
import numpy as np
from astropy.time import Time
import pint
import astropy.units as u
from astropy.io import fits
import pint.toa as toa
import time
from lstchain.io.io import dl2_params_lstcam_key
import pint.models as models
from pint.models.timing_model import (
        TimingModel,
        Component,
)
from pint.models import (
        parameter as p,
)

# %% [markdown]
# ### 1.1 Download the most updated ephemeris from the Jodrell Bank web and create a .par file with the model for the month corresponding for the file in /LSTpulsar_data/notebook1 and for the previous month

# %%
data_dir='/fefs/aswg/workspace/alvaro.mas/LSTpulsar_data'
eph_file=data_dir+'/notebook1/all.gro'
file=data_dir+'/notebook1/DL2/dl2_LST-1.Run02976.0000.h5'

# %%
df=pd.read_hdf(file,key=dl2_params_lstcam_key,float_precision=20)
times=df.dragon_time.values
t = Time(times,format='unix', scale='utc')
mjd_times=t.mjd

# %%
colnames=['PSR', 'RAJ1','RAJ2','RAJ3', 'DECJ1','DECJ2','DECJ3', 'START', 'FINISH', 't0geo', 'F0', 'F1', 'F2',
              'RMS','Observatory', 'EPHEM', 'PSR2']

df_ephem= pd.read_csv(eph_file, delimiter='\s+',names=colnames,header=None)

# %%
#Looking for the information for the epoch of the times
for i in range(0,len(df_ephem['START'])):
        if (mjd_times[0]>df_ephem['START'][i]) & (mjd_times[0]<df_ephem['FINISH'][i]):
            break
        elif (mjd_times[0]< df_ephem['START'][i]) & (i==0):
            print('No ephemeris available')
        elif (mjd_times[0]> df_ephem['START'][i]) & (mjd_times[0]> df_ephem['FINISH'][i])& (i==len(df_ephem['START'])):
            print('No ephemeris available')

# %%
i

# %% [markdown]
# #### Execute the following bloc for i=i and i=i-1

# %%
#Select componentes of the model
all_components = Component.component_types
selected_components = ["AbsPhase","AstrometryEquatorial", "Spindown","SolarSystemShapiro"]
component_instances = []

# Initiate the component instances (see PINT pulsar documentation)
for cp_name in selected_components:
    component_class = all_components[cp_name]  # Get the component class
    component_instance = component_class()  # Instantiate a component object
    component_instances.append(component_instance)
    
tm = TimingModel("pulsar_test", component_instances)


#Add first derivative of the frequency
f1 = p.prefixParameter(
        parameter_type="float",
        name="F1",
        value=0.0,
        units=u.Hz / (u.s),
        longdouble=True,
)

#Add second derivative of the frequency
f2 = p.prefixParameter(
        parameter_type="float",
        name="F2",
        value=0.0,
        units=u.Hz / (u.s)**2,
        longdouble=True,
)

tm.components["Spindown"].add_param(f1, setup=True)
tm.components["Spindown"].add_param(f2, setup=True)

f1=float(str(df_ephem['F1'][i].replace('D','E')))
f2=float(str(df_ephem['F2'][i].replace('D','E')))

#Give values to the parameters
params = {
            "PSR":(df_ephem['PSR'][i],) ,
            "RAJ": (str(df_ephem['RAJ1'][i])+':'+ str(df_ephem['RAJ2'][i])+':'+str(df_ephem['RAJ3'][i]),),
            "DECJ": (str(df_ephem['DECJ1'][i])+':'+ str(df_ephem['DECJ2'][i])+':'+str(df_ephem['DECJ3'][i]),),
            "START": (Time(df_ephem['START'][i], format="mjd", scale="tdb"),),
            "FINISH": (Time(df_ephem['FINISH'][i], format="mjd", scale="tdb"),),
            "EPHEM":(df_ephem['EPHEM'][i],),
            'PEPOCH':(Time(int(df_ephem['t0geo'][i]), format="mjd", scale="tdb"),),
            "F0": (df_ephem['F0'][i]*u.Hz,),
            "F1": (f1*u.Hz/u.s,),
            "F2":(f2*u.Hz/(u.s**2),),
            "TZRMJD":(Time(df_ephem['t0geo'][i], format="mjd", scale="tdb"),),
            "TZRFRQ":(0.0*u.Hz,),
            "TZRSITE":('coe',),
        }

#Create the model using PINT
for name, info in params.items():
        par = getattr(tm, name)  # Get parameter object from name
        par.quantity = info[0]  # set parameter value
        if len(info) > 1:
                if info[1] == 1:
                        par.frozen = False  # Frozen means not fit.
                        par.uncertainty = info[2]

tm.validate()
print(tm)
# Out:
# INFO     (pint.models.absolute_phase    ): TZRFRQ was 0.0 or None. Setting to infinite frequency.
# # Created: 2022-06-07T07:58:49.564895
# # PINT_version: 0.8.8
# # User: alvaro.mas
# # Host: cp01
# # OS: Linux-3.10.0-957.el7.x86_64-x86_64-with-centos-7.6.1810-Core
# # Format: pint
# PSR                               0531+21
# EPHEM                               DE200
# START              59123.0000000000000000
# FINISH             59154.0000000000000000
# DILATEFREQ                              N
# DMDATA                                  N
# NTOA                                    0
# CHI2                                  0.0
# RAJ                      5:34:31.97200000
# DECJ                    22:00:52.07000000
# PMRA                                  0.0
# PMDEC                                 0.0
# PX                                    0.0
# F0                  29.602547181765800133
# F1                           -3.67952e-10
# F2                              -7.05e-21
# PEPOCH             59138.0000000000000000
# TZRMJD             59138.0000002919987310
# TZRSITE                               coe
# TZRFRQ                                inf
# PLANET_SHAPIRO                          N

# %%
#Create the .par file
tm.as_parfile()
parname=str(os.path.basename(file).replace('.h5',''))+'_'+str(i)+'.par'
f=open(parname,"w+")
f.write(tm.as_parfile())
f.close()

# %%
# !ls
# Out:
# dl2_LST-1.Run02976.0000_415.par  dl2_LST-1.Run02976.0000_417.par
# dl2_LST-1.Run02976.0000_416.par  exercise_1.ipynb

# %% [markdown]
# ### 1.2. Create the .tim file for this file

# %%
timname=str(os.path.basename(file).replace('.h5',''))+'.tim'
timFile=open(timname,'w+')
timFile.write('FORMAT 1 \n')
for i in range(0,len(mjd_times)):
    timFile.write('lst '+'0.0 '+str(mjd_times[i])+' 0.0 '+ 'lst'+' \n')
timFile.close()

# %%
# !head ./dl2_LST-1.Run02976.0000.tim
# Out:
# FORMAT 1
# lst 0.0 59174.15089879001 0.0 lst
# lst 0.0 59174.15089879721 0.0 lst
# lst 0.0 59174.1508987976 0.0 lst
# lst 0.0 59174.150898798856 0.0 lst
# lst 0.0 59174.1508987999 0.0 lst
# lst 0.0 59174.150898806074 0.0 lst
# lst 0.0 59174.150898807995 0.0 lst
# lst 0.0 59174.15089880979 0.0 lst
# lst 0.0 59174.1508988108 0.0 lst

# %% [markdown]
# ### 1.3 Execute the scrit add_pulsarphase.py directly to the DL2 file to obtain the DL2_pulsar file. Do it using both models. Compare the phases obtained with both models and calculate the mean different between both phases for the events

# %% [markdown]
# ### For the correct month

# %%
# !add_pulsarphase --in-file /fefs/aswg/workspace/alvaro.mas/data/real/Crab/src_dependent/v0.9_crab/DL2/dl2_LST-1.Run02976.0000.h5  --ephem ./dl2_LST-1.Run02976.0000_416.par --output ./
# Out:
# Input file:/fefs/aswg/workspace/alvaro.mas/data/real/Crab/src_dependent/v0.9_crab/DL2/dl2_LST-1.Run02976.0000.h5
# Adding MJD time
# Creating .tim file
# Setting the .par file
# creating TOA list
# WARNING  (pint.observatory.topo_obs     ): No clock corrections found for observatory lst taken from file
# INFO     (pint.observatory.topo_obs     ): Applying GPS to UTC clock correction (~few nanoseconds)
# INFO     (pint.observatory.topo_obs     ): Loading GPS clock file /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/pint/data/runtime/gps2utc.clk for lst
# WARNING  (pint.observatory.clock_file   ): Data points out of range in clock file '/fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/pint/data/runtime/gps2utc.clk'
# INFO     (pint.observatory.topo_obs     ): Applying TT(TAI) to TT(BIPM2019) clock correction (~27 us)
# INFO     (pint.observatory.topo_obs     ): Loading BIPM clock file {self.bipm_fullpath} for {self.name}
# WARNING  (pint.toa                      ): No ephemeris provided to TOAs object or compute_TDBs. Using DE421
# INFO     (pint.solar_system_ephemerides ): Set solar system ephemeris to de421 from download
# # Created: 2022-06-07T08:01:02.226250
# # PINT_version: 0.8.8
# # User: alvaro.mas
# # Host: cp01
# # OS: Linux-3.10.0-957.el7.x86_64-x86_64-with-centos-7.6.1810-Core
# # Format: pint
# PSR                               0531+21
# EPHEM                               DE200
# START              59154.0000000000000000
# FINISH             59184.0000000000000000
# DILATEFREQ                              N
# DMDATA                                  N
# NTOA                                    0
# CHI2                                  0.0
# RAJ                      5:34:31.97200000
# DECJ                    22:00:52.07000000
# PMRA                                  0.0
# PMDEC                                 0.0
# PX                                    0.0
# F0                  29.601561703284300364
# F1                           -3.67917e-10
# F2                              -7.12e-21
# PEPOCH             59169.0000000000000000
# PLANET_SHAPIRO                          N
# TZRMJD             59169.0000001689986690
# TZRSITE                               coe
# TZRFRQ                                inf
#
# Calculating barycentric time and absolute phase
# INFO     (pint.observatory.special_locations): Observatory geocenter, loading GPS clock file /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/pint/data/runtime/gps2utc.clk
# WARNING  (pint.logging                  ): <class 'erfa.core.ErfaWarning'> ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/pint/logging.py:115: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   warn_(message, *args, **kwargs)
# INFO     (pint.observatory.special_locations): Applying TT(TAI) to TT(BIPM) clock correction (~27 us)
# INFO     (pint.observatory.special_locations): Observatory geocenter, loading BIPM clock file /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/pint/data/runtime/tai2tt_bipm2019.clk
# Generating new columns in DL2 DataFrame
# Writing outputfile in./dl2_LST-1.Run02976.0000_pulsar.h5
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'expected_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'expected_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'expected_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'expected_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'dist')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'dist')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'time_gradient_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'time_gradient_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'skewness_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'skewness_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'alpha')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'alpha')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'log_reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'log_reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'reco_disp_norm')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_disp_norm')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'reco_disp_sign')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_disp_sign')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'reco_disp_dx')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_disp_dx')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'reco_disp_dy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_disp_dy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'reco_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'reco_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'signed_time_gradient')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'signed_time_gradient')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'signed_skewness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'signed_skewness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'reco_alt')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_alt')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'reco_az')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_az')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'reco_type')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_type')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'gammaness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'gammaness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'expected_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'expected_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'expected_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'expected_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'dist')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'dist')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'time_gradient_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'time_gradient_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'skewness_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'skewness_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'alpha')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'alpha')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'off_angle')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'off_angle')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'log_reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'log_reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'reco_disp_norm')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_disp_norm')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'reco_disp_sign')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_disp_sign')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'reco_disp_dx')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_disp_dx')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'reco_disp_dy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_disp_dy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'reco_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'reco_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'signed_time_gradient')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'signed_time_gradient')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'signed_skewness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'signed_skewness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'reco_alt')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_alt')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'reco_az')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_az')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'reco_type')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_type')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'gammaness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'gammaness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'expected_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'expected_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'expected_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'expected_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'dist')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'dist')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'time_gradient_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'time_gradient_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'skewness_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'skewness_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'alpha')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'alpha')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'off_angle')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'off_angle')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'log_reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'log_reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'reco_disp_norm')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_disp_norm')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'reco_disp_sign')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_disp_sign')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'reco_disp_dx')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_disp_dx')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'reco_disp_dy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_disp_dy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'reco_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'reco_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'signed_time_gradient')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'signed_time_gradient')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'signed_skewness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'signed_skewness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'reco_alt')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_alt')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# ...
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'expected_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'expected_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'expected_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'expected_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'dist')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'dist')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'time_gradient_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'time_gradient_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'skewness_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'skewness_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'alpha')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'alpha')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'off_angle')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'off_angle')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'log_reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'log_reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'reco_disp_norm')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_disp_norm')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'reco_disp_sign')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_disp_sign')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'reco_disp_dx')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_disp_dx')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'reco_disp_dy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_disp_dy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'reco_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'reco_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'signed_time_gradient')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'signed_time_gradient')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'signed_skewness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'signed_skewness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'reco_alt')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_alt')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'reco_az')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_az')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'reco_type')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_type')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'gammaness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'gammaness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# Finished

# %%
phases_1=pd.read_hdf('dl2_LST-1.Run02976.0000_pulsar.h5',key=dl2_params_lstcam_key,float_precision=20)['pulsar_phase']

# %% [markdown]
# ### For the previous month

# %%
# !rm dl2_LST-1.Run02976.0000_pulsar.h5

# %%
# !add_pulsarphase --in-file /fefs/aswg/workspace/alvaro.mas/data/real/Crab/src_dependent/v0.9_crab/DL2/dl2_LST-1.Run02976.0000.h5  --ephem ./dl2_LST-1.Run02976.0000_415.par --output ./
# Out:
# Input file:/fefs/aswg/workspace/alvaro.mas/data/real/Crab/src_dependent/v0.9_crab/DL2/dl2_LST-1.Run02976.0000.h5
# Adding MJD time
# Creating .tim file
# Setting the .par file
# creating TOA list
# WARNING  (pint.observatory.topo_obs     ): No clock corrections found for observatory lst taken from file
# INFO     (pint.observatory.topo_obs     ): Applying GPS to UTC clock correction (~few nanoseconds)
# INFO     (pint.observatory.topo_obs     ): Loading GPS clock file /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/pint/data/runtime/gps2utc.clk for lst
# WARNING  (pint.observatory.clock_file   ): Data points out of range in clock file '/fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/pint/data/runtime/gps2utc.clk'
# INFO     (pint.observatory.topo_obs     ): Applying TT(TAI) to TT(BIPM2019) clock correction (~27 us)
# INFO     (pint.observatory.topo_obs     ): Loading BIPM clock file {self.bipm_fullpath} for {self.name}
# WARNING  (pint.toa                      ): No ephemeris provided to TOAs object or compute_TDBs. Using DE421
# INFO     (pint.solar_system_ephemerides ): Set solar system ephemeris to de421 from download
# # Created: 2022-06-07T08:02:47.197147
# # PINT_version: 0.8.8
# # User: alvaro.mas
# # Host: cp01
# # OS: Linux-3.10.0-957.el7.x86_64-x86_64-with-centos-7.6.1810-Core
# # Format: pint
# PSR                               0531+21
# EPHEM                               DE200
# START              59123.0000000000000000
# FINISH             59154.0000000000000000
# DILATEFREQ                              N
# DMDATA                                  N
# NTOA                                    0
# CHI2                                  0.0
# RAJ                      5:34:31.97200000
# DECJ                    22:00:52.07000000
# PMRA                                  0.0
# PMDEC                                 0.0
# PX                                    0.0
# F0                  29.602547181765800133
# F1                           -3.67952e-10
# F2                              -7.05e-21
# PEPOCH             59138.0000000000000000
# TZRMJD             59138.0000002919987269
# TZRSITE                               coe
# TZRFRQ                                inf
# PLANET_SHAPIRO                          N
#
# Calculating barycentric time and absolute phase
# INFO     (pint.observatory.special_locations): Observatory geocenter, loading GPS clock file /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/pint/data/runtime/gps2utc.clk
# WARNING  (pint.logging                  ): <class 'erfa.core.ErfaWarning'> ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/pint/logging.py:115: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   warn_(message, *args, **kwargs)
# INFO     (pint.observatory.special_locations): Applying TT(TAI) to TT(BIPM) clock correction (~27 us)
# INFO     (pint.observatory.special_locations): Observatory geocenter, loading BIPM clock file /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/pint/data/runtime/tai2tt_bipm2019.clk
# Generating new columns in DL2 DataFrame
# Writing outputfile in./dl2_LST-1.Run02976.0000_pulsar.h5
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'expected_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'expected_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'expected_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'expected_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'dist')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'dist')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'time_gradient_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'time_gradient_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'skewness_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'skewness_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'alpha')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'alpha')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'log_reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'log_reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'reco_disp_norm')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_disp_norm')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'reco_disp_sign')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_disp_sign')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'reco_disp_dx')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_disp_dx')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'reco_disp_dy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_disp_dy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'reco_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'reco_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'signed_time_gradient')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'signed_time_gradient')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'signed_skewness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'signed_skewness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'reco_alt')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_alt')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'reco_az')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_az')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'reco_type')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_type')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('on', 'gammaness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'gammaness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'expected_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'expected_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'expected_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'expected_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'dist')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'dist')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'time_gradient_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'time_gradient_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'skewness_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'skewness_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'alpha')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'alpha')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'off_angle')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'off_angle')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'log_reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'log_reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'reco_disp_norm')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_disp_norm')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'reco_disp_sign')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_disp_sign')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'reco_disp_dx')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_disp_dx')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'reco_disp_dy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_disp_dy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'reco_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'reco_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'signed_time_gradient')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'signed_time_gradient')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'signed_skewness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'signed_skewness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'reco_alt')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_alt')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'reco_az')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_az')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'reco_type')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_type')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_090', 'gammaness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'gammaness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'expected_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'expected_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'expected_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'expected_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'dist')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'dist')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'time_gradient_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'time_gradient_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'skewness_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'skewness_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'alpha')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'alpha')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'off_angle')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'off_angle')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'log_reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'log_reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'reco_disp_norm')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_disp_norm')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'reco_disp_sign')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_disp_sign')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'reco_disp_dx')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_disp_dx')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'reco_disp_dy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_disp_dy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'reco_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'reco_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'signed_time_gradient')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'signed_time_gradient')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'signed_skewness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'signed_skewness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_180', 'reco_alt')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_alt')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# ...
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'expected_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'expected_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'expected_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'expected_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'dist')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'dist')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'time_gradient_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'time_gradient_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'skewness_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'skewness_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'alpha')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'alpha')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'off_angle')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'off_angle')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'log_reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'log_reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'reco_disp_norm')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_disp_norm')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'reco_disp_sign')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_disp_sign')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'reco_disp_dx')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_disp_dx')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'reco_disp_dy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_disp_dy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'reco_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'reco_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'signed_time_gradient')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'signed_time_gradient')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'signed_skewness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'signed_skewness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'reco_alt')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_alt')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'reco_az')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_az')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'reco_type')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_type')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# WARNING  (pint.logging                  ): <class 'tables.exceptions.NaturalNameWarning'> object name is not a valid Python identifier: "('off_270', 'gammaness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/pulsar-lst1/lib/python3.7/site-packages/tables/path.py:91: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'gammaness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   NaturalNameWarning, stacklevel=2)
# Finished

# %%
phases_2=pd.read_hdf('dl2_LST-1.Run02976.0000_pulsar.h5',key=dl2_params_lstcam_key,float_precision=20)['pulsar_phase']

# %% [markdown]
# ### Compare

# %%
phases_1-phases_2
# Out:
# 0        0.085957
# 1        0.085957
# 2        0.085957
# 3        0.085957
# 4        0.085957
#            ...
# 42592    0.085958
# 42593    0.085958
# 42594    0.085958
# 42595    0.085958
# 42596    0.085958
# Name: pulsar_phase, Length: 42597, dtype: float128

# %%
# !rm dl2_LST-1.Run02976.0000_pulsar.h5
# !rm dl2_LST-1.Run02976.0000_415.par
# !rm dl2_LST-1.Run02976.0000_416.par

# %% [markdown]
# --------------------------------------------------------------------------

# %% [markdown]
# ### 1.4 For the merged file in LSTpulsar_data/notebook2 build the phaseogram with 60 bins and get the P1/P2 ratio. Use a gammaness_cut>0.4 and alpha_cut<15 for E<100 GeV and gammaness_cut>0.6 and alpha_cut<10 for E>100 GeV

# %%
from ptiming_ana.phaseogram import *

# %%
h=PulsarAnalysis()
h.setLSTInputFile(filename=data_dir+'/notebook2/pulsar_sample.h5')
h.setBackgroundLimits([0.52,0.87])
h.setPeaklimits(P1_limits=[0,0.026,0.983,1],P2_limits=[0.377,0.422],P3_limits=[0.026,0.377])
h.setBinning(nbins=60,xmin=0,xmax=1)
h.setTimeInterval(tint=3600*50)
h.setParamCuts(gammaness_cut=[0.6,0.8],alpha_cut=[15,10],zd_cut=35,energy_binning_cut=[0.01,0.1,1000])
h.setEnergybinning([0,0.1,100])

# %%
h.run()
# Out:
# --> Initializing...
#     Reading LST-1 data file
#     Finishing reading. Total time is 5.350203256474601 h
#     Finishing filtering events:
#         gammaness cut:[0.6, 0.8]
#         alpha cut:[15, 10]
#         theta2 cut:None
#         zd cut:35
#         energy binning for the cuts:[0.01, 0.1, 1000]
#
#
# --> Calculating statistics every 3000.0 minutes...
# No fit has been done since no fit parameters has been set
#
# --> Performing energy-dependent analysis...
# Creating object in energy range (TeV):0.00-0.10
# Calculating statistics...
# No fit has been done since no fit parameters has been set
# Creating object in energy range (TeV):0.10-100.00
# Calculating statistics...
# No fit has been done since no fit parameters has been set
#
# FINISHED

# %%
h.draw_phaseogram(phase_limits=[0,2],colorhist='blue')

# %% [markdown]
# ### 1.5 Check the Nexcess and the significance of the P1, P2 and the bridge defined as the region between P1 and P2

# %%
peak_stats,period_stats=h.show_Presults()
# Out:
# RESULTS FOR THE PEAK STATISTICS:
#
#                         P1            P2         P1+P2             P3
# Significance      5.012911      3.954139      6.002287       0.988595
# Nex             820.100000    662.500000   1482.600000     613.700000
# Nex_error       165.061527    168.693573    248.504333     620.779481
# Number        24354.000000  25291.000000  49645.000000  192716.000000
# noff          23533.900000  24628.500000  48162.400000  192102.300000
# sign_t_ratio      2.461466      1.941582      2.947274       0.485425
# s/n ratio         5.345888      4.221501      6.755693       1.400199
#
# P1/P2 ratio=1.24+/-0.40
#
#
#
# RESULTS FOR THE PERIODICITY SEARCH:
#
#                     Chi_square_test    Zn_test     H_test
# Statistic                 95.408929  58.902195  24.446490
# p-value                    0.001888   0.000011   0.000059
# Number of $\sigma$         6.263002   4.253626   3.848218

# %% [markdown]
# ### 1.6 Calculate the significance of each peak at E>100GeV and E<100 GeV

# %%
sp,ss=h.show_EnergyPresults()
# Out:
# ENERGY RANGE (TeV):0.00-0.10
#
# RESULTS FOR THE PEAK STATISTICS:
#
#                         P1            P2         P1+P2             P3
# Significance      4.410012      3.470141      5.274839       0.654060
# Nex             691.708571    557.485714   1249.194286     389.388571
# Nex_error       158.137621    161.659370    238.138117     595.339955
# Number        22347.000000  23220.000000  45567.000000  177157.000000
# noff          21655.291429  22662.514286  44317.805714  176767.611429
# sign_t_ratio      2.226508      1.751990      2.663138       0.330219
# s/n ratio         4.700468      3.703222      5.933909       0.926151
#
# P1/P2 ratio=1.24+/-0.46
#
#
#
# RESULTS FOR THE PERIODICITY SEARCH:
#
#                     Chi_square_test    Zn_test     H_test
# Statistic                 91.422429  53.353809  18.735877
# p-value                    0.004335   0.000072   0.000577
# Number of $\sigma$         6.132138   3.800905   3.249788
#
#
#
# -------------------------------------------------------------------
# ENERGY RANGE (TeV):0.10-100.00
#
# RESULTS FOR THE PEAK STATISTICS:
#
#                        P1           P2        P1+P2            P3
# Significance     2.761110     2.207794     3.325098      1.275286
# Nex            128.391429   105.014286   233.405714    224.311429
# Nex_error       47.305396    48.205493    71.025635    175.890597
# Number        2007.000000  2071.000000  4078.000000  15559.000000
# noff          1878.608571  1965.985714  3844.594286  15334.688571
# sign_t_ratio     7.978597     6.379717     9.608316      3.685111
# s/n ratio        2.962224     2.368417     3.764317      1.811398
#
# P1/P2 ratio=1.22+/-0.72
#
#
#
# RESULTS FOR THE PERIODICITY SEARCH:
#
#                     Chi_square_test    Zn_test    H_test
# Statistic                 77.499287  37.369063  3.381374
# p-value                    0.053505   0.010565  0.260335
# Number of $\sigma$         5.719226   2.305668  0.642314
#
#
#
# -------------------------------------------------------------------
