# %% [markdown]
# # Exercise 1. DL2 files and PINT

# %%
import pandas as pd
import os
import numpy as np
from astropy.time import Time
import pint
import astropy.units as u
from astropy.io import fits
import pint.toa as toa
import time
from lstchain.io.io import dl2_params_lstcam_key
import pint.models as models
from pint.models.timing_model import (
        TimingModel,
        Component,
)
from pint.models import (
        parameter as p,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_20946/3107688716.py in <module>
#       3 import numpy as np
#       4 from astropy.time import Time
# ----> 5 import pint
#       6 import astropy.units as u
#       7 from astropy.io import fits
#
# ModuleNotFoundError: No module named 'pint'

# %% [markdown]
# ### 1.1 Download the most updated ephemeris from the Jodrell Bank web and create a .par file with the model for the month corresponding for the file in /LSTpulsar_data/notebook1 and for the previous month

# %%
data_dir='/fefs/aswg/workspace/alvaro.mas/LSTpulsar_data'
eph_file=data_dir+'/all.gro'
file=data_dir+'/DL2/dl2_LST-1.Run02976.0000.h5'

# %%
df=pd.read_hdf(file,key=dl2_params_lstcam_key,float_precision=20)
times=df.dragon_time.values
t = Time(times,format='unix', scale='utc')
mjd_times=t.mjd

# %%
colnames=['PSR', 'RAJ1','RAJ2','RAJ3', 'DECJ1','DECJ2','DECJ3', 'START', 'FINISH', 't0geo', 'F0', 'F1', 'F2',
              'RMS','Observatory', 'EPHEM', 'PSR2']

df_ephem= pd.read_csv(eph_file, delimiter='\s+',names=colnames,header=None)

# %%
#Looking for the information for the epoch of the times
for i in range(0,len(df_ephem['START'])):
        if (mjd_times[0]>df_ephem['START'][i]) & (mjd_times[0]<df_ephem['FINISH'][i]):
            break
        elif (mjd_times[0]< df_ephem['START'][i]) & (i==0):
            print('No ephemeris available')
        elif (mjd_times[0]> df_ephem['START'][i]) & (mjd_times[0]> df_ephem['FINISH'][i])& (i==len(df_ephem['START'])):
            print('No ephemeris available')

# %%
i
# Out:
# 417

# %% [markdown]
# #### Execute the following bloc for i=i and i=i-1

# %%
#Select componentes of the model
all_components = Component.component_types
selected_components = ["AbsPhase","AstrometryEquatorial", "Spindown","SolarSystemShapiro"]
component_instances = []

# Initiate the component instances (see PINT pulsar documentation)
for cp_name in selected_components:
    component_class = all_components[cp_name]  # Get the component class
    component_instance = component_class()  # Instantiate a component object
    component_instances.append(component_instance)
    
tm = TimingModel("pulsar_test", component_instances)

#Add second derivative of the frequency
f2 = p.prefixParameter(
        parameter_type="float",
        name="F2",
        value=0.0,
        units=u.Hz / (u.s) ** 2,
        longdouble=True,
)

tm.components["Spindown"].add_param(f2, setup=True)

#Add START and FINISH parameters
tm.add_param_from_top(
            p.MJDParameter(name="START", description="Start MJD for fitting"), ""
        )
tm.add_param_from_top(
            p.MJDParameter(name="FINISH", description="End MJD for fitting"), ""
    )

f1=float(str(df_ephem['F1'][i].replace('D','E')))
f2=float(str(df_ephem['F2'][i].replace('D','E')))

#Give values to the parameters
params = {
            "PSR":(df_ephem['PSR'][i],) ,
            "RAJ": (str(df_ephem['RAJ1'][i])+':'+ str(df_ephem['RAJ2'][i])+':'+str(df_ephem['RAJ3'][i]),),
            "DECJ": (str(df_ephem['DECJ1'][i])+':'+ str(df_ephem['DECJ2'][i])+':'+str(df_ephem['DECJ3'][i]),),
            "START": (Time(df_ephem['START'][i], format="mjd", scale="tdb"),),
            "FINISH": (Time(df_ephem['FINISH'][i], format="mjd", scale="tdb"),),
            "EPHEM":(df_ephem['EPHEM'][i],),
            'PEPOCH':(Time(int(df_ephem['t0geo'][i]), format="mjd", scale="tdb"),),
            "F0": (df_ephem['F0'][i]*u.Hz,),
            "F1": (f1*u.Hz/u.s,),
            "F2":(f2*u.Hz/(u.s**2),),
            "TZRMJD":(Time(df_ephem['t0geo'][i], format="mjd", scale="tdb"),),
            "TZRFRQ":(0.0*u.Hz,),
            "TZRSITE":('coe',),
        }

#Create the model using PINT
for name, info in params.items():
        par = getattr(tm, name)  # Get parameter object from name
        par.quantity = info[0]  # set parameter value
        if len(info) > 1:
                if info[1] == 1:
                        par.frozen = False  # Frozen means not fit.
                        par.uncertainty = info[2]

tm.validate()
print(tm)
# Out:
# # Created: 2022-06-03T13:59:19.900650
# # PINT_version: 0.8.4
# # User: alvaro.mas
# # Host: cp01
# # OS: Linux-3.10.0-957.el7.x86_64-x86_64-with-glibc2.10
# PSR                               0531+21
# EPHEM                               DE200
# START              59184.0000000000000000
# FINISH             59215.0000000000000000
# DILATEFREQ                              N
# DMDATA                                  N
# NTOA                                    0
# CHI2                                  0.0
# START              59184.0000000000000000
# FINISH             59215.0000000000000000
# RAJ                      5:34:31.97200000
# DECJ                    22:00:52.07000000
# PMRA                                  0.0
# PMDEC                                 0.0
# PX                                    0.0
# F0                  29.600576318753400784
# F1              -3.6788400000000000884e-10
# F2                               1.68e-20
# PEPOCH             59200.0000000000000000
# TZRMJD             59200.0000000290019671
# TZRSITE                               coe
# TZRFRQ                                inf
# PLANET_SHAPIRO                          N

# %%
#Create the .par file
tm.as_parfile()
parname=str(os.path.basename(file).replace('.h5',''))+'_'+str(i)+'.par'
f=open(parname,"w+")
f.write(tm.as_parfile())
f.close()

# %% [markdown]
# ### 1.2. Create the .tim file for this file

# %%
timname=str(os.path.basename(file).replace('.h5',''))+'.tim'
timFile=open(timname,'w+')
timFile.write('FORMAT 1 \n')
for i in range(0,len(mjd_times)):
    timFile.write('lst '+'0.0 '+str(mjd_times[i])+' 0.0 '+ 'lst'+' \n')
timFile.close()

# %% [markdown]
# ### 1.3 Execute the scrit add_pulsarphase.py directly to the DL2 file to obtain the DL2_pulsar file. Do it using both models. Compare the phases obtained with both models and calculate the mean different between both phases for the events

# %%
# !ls
# Out:
# dl2_LST-1.Run02976.0000_416.par  dl2_LST-1.Run02976.0000.tim  exercise_2.ipynb
# dl2_LST-1.Run02976.0000_417.par  exercise_1.ipynb

# %%
# !add_pulsarphase --in-file /fefs/aswg/workspace/alvaro.mas/data/real/Crab/src_dependent/v0.9_crab/DL2/dl2_LST-1.Run02976.0000.h5  --ephem ./dl2_LST-1.Run02976.0000_416.par --output ./

# %%
phases_1=pd.read_hdf('dl2_LST-1.Run02976.0000_pulsar.h5',key=dl2_params_lstcam_key,float_precision=20)['pulsar_phase']

# %%
# !add_pulsarphase --in-file /fefs/aswg/workspace/alvaro.mas/data/real/Crab/src_dependent/v0.9_crab/DL2/dl2_LST-1.Run02976.0000.h5  --ephem ./dl2_LST-1.Run02976.0000_417.par --output ./
# Out:
# Input file:/fefs/aswg/workspace/alvaro.mas/data/real/Crab/src_dependent/v0.9_crab/DL2/dl2_LST-1.Run02976.0000.h5
# Adding MJD time
# Creating .tim file
# Setting the .par file
# creating TOA list
# Data points out of range in clock file '/fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/pint/data/runtime/time.dat'
# No ephemeris provided to TOAs object or compute_TDBs. Using DE421
# # Created: 2022-06-03T14:25:37.787173
# # PINT_version: 0.8.4
# # User: alvaro.mas
# # Host: cp01
# # OS: Linux-3.10.0-957.el7.x86_64-x86_64-with-glibc2.10
# PSR                               0531+21
# EPHEM                               DE200
# START              59184.0000000000000000
# FINISH             59215.0000000000000000
# DILATEFREQ                              N
# DMDATA                                  N
# NTOA                                    0
# CHI2                                  0.0
# RAJ                      5:34:31.97200000
# DECJ                    22:00:52.07000000
# PMRA                                  0.0
# PMDEC                                 0.0
# PX                                    0.0
# F0                  29.600576318753400784
# F1              -3.6788400000000000884e-10
# F2                               1.68e-20
# PEPOCH             59200.0000000000000000
# PLANET_SHAPIRO                          N
# TZRMJD             59200.0000000290019676
# TZRSITE                               coe
# TZRFRQ                                inf
#
# Calculating barycentric time and absolute phase
# Generating new columns in DL2 DataFrame
# Writing outputfile in./dl2_LST-1.Run02976.0000_pulsar.h5
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'expected_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'expected_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'dist')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'time_gradient_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'skewness_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'alpha')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'log_reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_disp_norm')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_disp_sign')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_disp_dx')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_disp_dy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'signed_time_gradient')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'signed_skewness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_alt')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_az')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'reco_type')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('on', 'gammaness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'expected_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'expected_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'dist')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'time_gradient_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'skewness_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'alpha')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'off_angle')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'log_reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_disp_norm')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_disp_sign')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_disp_dx')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_disp_dy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'signed_time_gradient')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'signed_skewness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_alt')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_az')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'reco_type')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_090', 'gammaness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'expected_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'expected_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'dist')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'time_gradient_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'skewness_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'alpha')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'off_angle')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'log_reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_disp_norm')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_disp_sign')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_disp_dx')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_disp_dy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'signed_time_gradient')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'signed_skewness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_alt')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_az')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'reco_type')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_180', 'gammaness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'expected_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'expected_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'dist')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'time_gradient_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'skewness_from_source')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'alpha')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'off_angle')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'log_reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_energy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_disp_norm')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_disp_sign')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_disp_dx')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_disp_dy')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_src_x')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_src_y')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'signed_time_gradient')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'signed_skewness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_alt')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_az')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'reco_type')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /fefs/aswg/workspace/alvaro.mas/software/miniconda3/envs/lst-dev/lib/python3.8/site-packages/tables/path.py:137: NaturalNameWarning: object name is not a valid Python identifier: "('off_270', 'gammaness')"; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# Finished

# %%
phases_2=pd.read_hdf('dl2_LST-1.Run02976.0000_pulsar.h5',key=dl2_params_lstcam_key,float_precision=20)['pulsar_phase']

# %%
phases_1-phases_2
# Out:
# 0        0.006896
# 1        0.006896
# 2        0.006896
# 3        0.006896
# 4        0.006896
#            ...
# 42592    0.006896
# 42593    0.006896
# 42594    0.006896
# 42595    0.006896
# 42596    0.006896
# Name: pulsar_phase, Length: 42597, dtype: float128

# %% [markdown]
# --------------------------------------------------------------------------

# %%
from ptiming_ana.phaseogram import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_20946/3277048899.py in <module>
# ----> 1 from ptiming_ana.phaseogram import *
#
# ModuleNotFoundError: No module named 'ptiming_ana'

# %% [markdown]
# ### 1.4 For the merged file in LSTpulsar_data/notebook2 build the phaseogram with 60 bins and get the P1/P2 ratio. Use a gammaness_cut>0.4 and alpha_cut<15 for E<100 GeV and gammaness_cut>0.6 and alpha_cut<10 for E>100 GeV

# %%
h=PulsarAnalysis()
h.setLSTInputFile(filename=data_dir+'/notebook2/')
h.setBackgroundLimits([0.52,0.87])
h.setPeaklimits(P1_limits=[0,0.026,0.983,1],P2_limits=[0.377,0.422],P3_limits=[0.026,0.377])
h.setBinning(nbins=60,xmin=0,xmax=1)
h.setTimeInterval(tint=3600*50)
h.setParamCuts(gammaness_cut=0.7,alpha_cut=10)
#h.setFittingParams(model='lorentzian',binned=False)
#h.setEnergybinning([0,0.1,100])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_20946/2100700657.py in <module>
# ----> 1 h=PulsarAnalysis()
#       2 h.setLSTInputFile(filename=data_dir+'/notebook2/')
#       3 h.setBackgroundLimits([0.52,0.87])
#       4 h.setPeaklimits(P1_limits=[0,0.026,0.983,1],P2_limits=[0.377,0.422],P3_limits=[0.026,0.377])
#       5 h.setBinning(nbins=60,xmin=0,xmax=1)
#
# NameError: name 'PulsarAnalysis' is not defined

# %%
h.run()
# Out:
# --> Initializing...
#     Reading LST-1 data file
# --> Calculating statistics every 3000.0 minutes...
# No fit has been done since no fit parameters has been set
#
# --> Performing energy-dependent analysis...
# No Energy Analysis was performed. Check that you set the right energy params
#
# FINISHED

# %%
h.draw_phaseogram(phase_limits=[0,2],colorhist='blue')

# %% [markdown]
# ### 1.5 Check the Nexcess and the significance of the P1, P2 and the bridge defined as the region between P1 and P2

# %%
peak_stats,period_stats=h.show_Presults()
# Out:
# RESULTS FOR THE PEAK STATISTICS:
#
#                        P1           P2        P1+P2            P3
# Significance     2.998690     0.950617     2.634409      0.315473
# Nex            191.494286    61.842857   253.337143     76.174286
# Nex_error       64.734507    65.331508    96.822405    241.459910
# Number        3753.000000  3789.000000  7542.000000  29148.000000
# noff          3561.505714  3727.157143  7288.662857  29071.825714
# sign_t_ratio     3.639059     1.153621     3.196987      0.382843
# s/n ratio        3.208773     1.012980     2.967392      0.446758
#
# P1/P2 ratio=3.10+/-3.43
#
#
#
# RESULTS FOR THE PERIODICITY SEARCH:
#
#                     Chi_square_test    Zn_test    H_test
# Statistic                 51.486578  25.105625  2.175809
# p-value                    0.376691   0.197420  0.420642
# Number of $\sigma$         5.377951   0.850873  0.200250

# %% [markdown]
# ### 1.6 Calculate the significance of each peak at E>100GeV and E<100 GeV

# %%
sp,ss=h.show_EnergyPresults()
# Out:
# No energy-dependent analysis has been done
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_10850/682138437.py in <cell line: 1>()
# ----> 1 sp,ss=h.show_EnergyPresults()
#
# TypeError: cannot unpack non-iterable NoneType object

# %% [markdown]
# ### 1.7 Try to fit the phaseogram to a Double Lorentzian Distibution

# %%
histo=h.draw_phaseogram(phase_limits=[0,2],colorhist='blue',fit=True)

# %%
res=h.show_fit_results()
